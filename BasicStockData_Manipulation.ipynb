# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/Learn-PyForFinance/blob/main/BasicStockData_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Import Libraries
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import yfinance as yf

# %%
# @title Make Dataset
import yfinance as yf

start = '2018-01-01'
end = '2023-12-31'

data = yf.download('TSLA', start=start, end=end)
data.to_csv('tsla.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.read_csv('tsla.csv', index_col = 'Date', parse_dates=['Date'])
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   20.799999   21.474001   20.733334   21.368668   21.368668
# 2018-01-03   21.400000   21.683332   21.036667   21.150000   21.150000
# 2018-01-04   20.858000   21.236668   20.378668   20.974667   20.974667
# 2018-01-05   21.108000   21.149332   20.799999   21.105333   21.105333
# 2018-01-08   21.066668   22.468000   21.033333   22.427334   22.427334
# ...                ...         ...         ...         ...         ...
# 2023-08-04  260.970001  264.769989  253.110001  253.860001  253.860001
# 2023-08-07  251.449997  253.649994  242.759995  251.449997  251.449997
# 2023-08-08  247.449997  250.919998  245.009995  249.699997  249.699997
# 2023-08-09  250.869995  251.100006  241.899994  242.190002  242.190002
# 2023-08-10  245.399994  251.800003  243.000000  245.339996  245.339996
#
#                Volume
# Date
# 2018-01-02   65283000
# 2018-01-03   67822500
# 2018-01-04  149194500
# ...

# %%
df['Adj Close'].plot()
plt.show()

# %%
df = pd.read_csv('tsla.csv', index_col = 'Date', parse_dates=['Date'])

# %%
df['100ma'] = df['Adj Close'].rolling(window=100, min_periods=0).mean()
# df.dropna(inplace=True)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-04  260.970001  264.769989  253.110001  253.860001  253.860001
# 2023-08-07  251.449997  253.649994  242.759995  251.449997  251.449997
# 2023-08-08  247.449997  250.919998  245.009995  249.699997  249.699997
# 2023-08-09  250.869995  251.100006  241.899994  242.190002  242.190002
# 2023-08-10  245.399994  251.800003  243.000000  245.339996  245.339996
#
#                Volume     100ma
# Date
# 2023-08-04   99242600  215.5630
# 2023-08-07  111097900  216.2449
# 2023-08-08   96642200  216.9374
# 2023-08-09  101596300  217.5180
# 2023-08-10  108706990  218.1701

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax1.plot(df.index, df['Adj Close'])
ax1.plot(df.index, df['100ma'])
plt.show()

# %%
ax2 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2.bar(df.index, df['Volume'])
plt.show()
